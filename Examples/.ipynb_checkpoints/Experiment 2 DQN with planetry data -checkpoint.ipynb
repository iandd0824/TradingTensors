# %% [markdown]
# # Enhancing State Space with Planetry Data?
#
# In this experiment, lets explore how the position of Moon affect our Agent's behaviour. Planet Calculation is made based datetime values using Swiss Ephemeris method (pyswisseph). (This experiment is purely for fun as there has been no proven evidence in the predictive power of this additional information)

# %%
from tradingtensors.Environments.CustomEnvs import OandaEnv
from tradingtensors.Agents.Q_learning import DQNAgent

#Define Environment
env = OandaEnv(
    INSTRUMENT = "EUR_USD", 
    TIMEFRAME = "H1", 
    lookback_period= 3,
    trade_duration=3,
    planet_data={"Moon" : ["right asc.", "declination", "distance"]}, # Require these coordinates of Moon
    PLANET_FORWARD_PERIOD=2, #Look ahead 2 periods of Moon Coordinates 

)

#Define Agent - DQN

PATH = r'train\DQN2\20180820'

agent = DQNAgent(
    env= env,
    PARENT_PATH = PATH #Path to save your models
)
# Out:
# C:\Users\pc\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Can not use swisseph package!
# WARNING:tensorflow:From c:\users\pc\documents\ml\tradingtensors\tradingtensors\Agents\BaseQ.py:40: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead

# %%
agent.train(
TRAIN_EPISODES = 50,
CONVERGENCE_THRESHOLD=2000 #Setting a more stringent convergence criteria than before
) #use Default Settings
# Out:
# End of Episode 1, Total Reward is -14.30000000001835, Average Reward is -0.168
# Percentage of time spent on exploring (Random Action): 96 %
#
# End of Episode 2, Total Reward is 149.40000000001513, Average Reward is 1.737
# Percentage of time spent on exploring (Random Action): 93 %
#
# End of Episode 3, Total Reward is -173.50000000000855, Average Reward is -2.041
# Percentage of time spent on exploring (Random Action): 90 %
#
# End of Episode 4, Total Reward is 7.899999999976302, Average Reward is 0.094
# Percentage of time spent on exploring (Random Action): 86 %
#
# End of Episode 5, Total Reward is 129.29999999997437, Average Reward is 1.521
# Percentage of time spent on exploring (Random Action): 83 %
#
# End of Episode 6, Total Reward is -128.19999999998282, Average Reward is -1.583
# Percentage of time spent on exploring (Random Action): 80 %
#
# End of Episode 7, Total Reward is 199.39999999999182, Average Reward is 2.240
# ...

# %%
agent.trainSummary()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-33cbee7b8ec4> in <module>()
# ----> 1 agent.trainSummary()
#
# c:\users\pc\documents\ml\tradingtensors\tradingtensors\Agents\Q_learning.py in trainSummary(self, TOP_N)
#     280
#     281         #Plot Total Reward
# --> 282         rewardPlot(self.reward_record, self.best_models, 'Total', TOP_N)
#     283
#     284         #Plot Average Reward
#
# c:\users\pc\documents\ml\tradingtensors\tradingtensors\Agents\visual_utils.py in rewardPlot(record, best_models, TYPE, top_n)
#      16     top_n_episodes = top_10_episodes[:top_n]
#      17     top_n_index = top_10_index[:top_n]
# ---> 18     top_n_rewards = arr[top_n_index]
#      19
#      20
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
'''Surprisingly, model is able to converge even with a more stringent criteria. Maybe pure luck?'''
agent.episodeReview(170)

# %%
''' Test Case does not do that badly either'''
agent.test(44)
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\Henry\Documents\Python Stuff\Upwork Trial\Forex Ai\github\tradingtensors\Examples\Models\2216_Episode44.ckpt
# Summary Statistics for Episode 0
#
# Total Trades            | 48        (Buy)19       (Sell)29
# Profit (in pips)        | 85.60   (Buy)59.90   (Sell)25.70
# Win Ratio               | 54.17%    (Buy)63.16%   (Sell)48.28 %
# Average Trade Duration  | 3.00

# %% [markdown]
# #  Live Trading

# %%
'''Ready to take Model 44 live?'''
agent.liveTrading(
    MODEL_EPS=44
)
